# %%
{
  "Comment": "mui-demo",
  "StartAt": "RunETLJob",
  "States": {
    "RunETLJob": {
      "Type": "Task",
      "Resource": "arn:aws:states:::glue:startJobRun.sync",
      "Parameters": {
        "JobName": "mui-glue"
      },
      "End": true
    }
  }
}
